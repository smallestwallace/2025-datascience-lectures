# %% [markdown]
# ## Lecture 4: In Class Activity
#
#
# Your Name:  Nathan Wallace
#
# Your UID:   U1186463
#
# Your E-Mail:U1186463@utah.edu
#
# For this activity first import a small data set containing 10 measurements of CO$_2$ levels and global temperatures. You can do this with the read_csv command from the pandas library as follows:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
my_data = pd.read_csv("global_warming.csv")

# %% [markdown]
# # Item 1
#
# Print the first few rows of the my_data data frame. Then create lists storing the CO_2 and temperature values. Compute the mean and median of the temperature measurements.

# %%
# Your code here
print(my_data[0:3])
print()
CO_2 = my_data["CO_2"].tolist()
temp = my_data["Temp"].tolist()
print(np.mean(temp))
print(np.median(temp))
# Out:
#    CO_2  Temp
# 0   314  13.9
# 1   317  14.0
# 2   320  13.9
#
# 14.170000000000002
# 14.1

# %% [markdown]
# # Item 2
#
# Make a scatterplot of CO_2 versus temperature. Is there a strong relationship between these two variables? What is the correlation coefficient? Can we infer that increasing carbon dioxide levels will increase global temperature?

# %%
# Your code here
plt.scatter(temp,CO_2)
coeff = np.corrcoef(temp,CO_2)
plt.title('CO_2 levels vs. Temperature')
plt.xlabel('Temp ()')
plt.ylabel('CO_2 levels ()')
print('The correlation coefficient of the data is ', coeff[0, 1])
plt.show()
# Out:
# The correlation coefficient of the data is  0.8919763551653175

# %% [markdown]
# *Your answers here.*
#
# There appears to be a strong relationship between the two variables, as the correlation coefficient is 0.89.
#
# Ignoring all information that we aren't given in this file, we cannot infer that increasing carbon dioxide levels will increase global temperature, as correlation does not imply causation. However, with more knowledge of the systems and interactions involved, it is very possible that we could make that claim.

# %% [markdown]
# # Item 3
#
# Change the last temperature measurement from 14.4 degrees to 144 degrees which could have happened if there was a small error in manual data entry.
#
# How are the mean and median affected?
#
# How are the scatterplot and the correlation coefficient affected?
#
# Are the mean, median, and correlation coefficient robust to outliers and data entry errors?

# %%
print('Former values:')
print(np.mean(temp))
print(np.median(temp))
print('The correlation coefficient of the data is ', coeff[0, 1])
temp[-1] = 144
print('New values:')
print(np.mean(temp))
print(np.median(temp))
plt.scatter(temp,CO_2)
coeff = np.corrcoef(temp,CO_2)
plt.title('CO_2 levels vs. Temperature')
plt.xlabel('Temp ()')
plt.ylabel('CO_2 levels ()')
print('The correlation coefficient of the data is ', coeff[0, 1])
plt.show()
# Your code here
# Out:
# Former values:
# 14.170000000000002
# 14.1
# The correlation coefficient of the data is  0.8919763551653175
# New values:
# 27.130000000000003
# 14.1
# The correlation coefficient of the data is  0.5745303015462886

# %% [markdown]
# *Your answers here.*
#
# The mean increases significantly.
#
# The median does not change.
#
# The correlation coefficient decreases significantly.
#
# The correlation coefficient is a measure of how linear the graph is, or how well a single line can be fit to the data.
#
# Only the median appears to be robust to outliers and data entry errors.
#
# This is as expected, as the median considers the values in order and is only affected by those at the center of the range. The other two calculations weight each data point equally.
#
# *Improved answer using Microsoft Copilot AI:* Prompt: "Is this a good answer to the following question:" Then added the question and my answer in the previous paragraph.
#
# *This is expected because the median considers the values in order and is only affected by the central values, making it less sensitive to extreme values. In contrast, the mean and correlation coefficient are not robust to outliers and data entry errors, as they weight each data point equally, causing them to be significantly influenced by extreme values.*
